# %%
x=runif(100,0,1)
y=x^2+x+1+rnorm(100)
w=x^2
plot(x,y)
indices=sample(1:100,5,replace=F)
LM=lm(y[indices]~x[indices])
QM=lm(y[indices]~x[indices]+w[indices])
le=numeric(10000)
qe=numeric(10000)
for (i in 1:10000) {j=sample(1:100,1); le[i]=x[j]^2+x[j]+1+rnorm(1)-LM$coefficients[1]-LM$coefficients[2]*x[j]}
for (i in 1:10000) {j=sample(1:100,1); qe[i]=x[j]^2+x[j]+1+rnorm(1)-QM$coefficients[1]-QM$coefficients[2]*x[j]-QM$coefficients[3]*x[j]^2}
mean(le^2)
mean(qe^2)
# Out:
# [1] 1.127448
# [1] 1.337784
# plot without title

# %%
?runif

# %%
# Change parameters
x=runif(100,0,2)
y=x^2+x+1+rnorm(100)
w=x^2
plot(x,y)
indices=sample(1:100,10,replace=F)
LM=lm(y[indices]~x[indices])
QM=lm(y[indices]~x[indices]+w[indices])
le=numeric(10000)
qe=numeric(10000)
# Calculate MSE for both models
for (i in 1:10000) {j=sample(1:100,1); le[i]=x[j]^2+x[j]+1+rnorm(1)-LM$coefficients[1]-LM$coefficients[2]*x[j]}
for (i in 1:10000) {j=sample(1:100,1); qe[i]=x[j]^2+x[j]+1+rnorm(1)-QM$coefficients[1]-QM$coefficients[2]*x[j]-QM$coefficients[3]*x[j]^2}
mean(le^2)
mean(qe^2)
# Out:
# [1] 1.703084
# [1] 1.851622
# plot without title

# %%
# Change parameters
x=runif(100,0,2)
y=x^2+x+1+rnorm(100)
w=x^2
plot(x,y)
indices=sample(1:100,25,replace=F)
LM=lm(y[indices]~x[indices])
QM=lm(y[indices]~x[indices]+w[indices])
le=numeric(10000)
qe=numeric(10000)
# Calculate MSE for both models
for (i in 1:10000) {j=sample(1:100,1); le[i]=x[j]^2+x[j]+1+rnorm(1)-LM$coefficients[1]-LM$coefficients[2]*x[j]}
for (i in 1:10000) {j=sample(1:100,1); qe[i]=x[j]^2+x[j]+1+rnorm(1)-QM$coefficients[1]-QM$coefficients[2]*x[j]-QM$coefficients[3]*x[j]^2}
mean(le^2)
mean(qe^2)
# Out:
# [1] 1.197376
# [1] 1.199358
# plot without title

# %%
# Change parameter to length of 10 
x=runif(100,0,10)
y=x^2+x+1+rnorm(100)
w=x^2
plot(x,y)
indices=sample(1:100,25,replace=F)
LM=lm(y[indices]~x[indices])
QM=lm(y[indices]~x[indices]+w[indices])
le=numeric(10000)
qe=numeric(10000)
# Calculate MSE for both models
for (i in 1:10000) {j=sample(1:100,1); le[i]=x[j]^2+x[j]+1+rnorm(1)-LM$coefficients[1]-LM$coefficients[2]*x[j]}
for (i in 1:10000) {j=sample(1:100,1); qe[i]=x[j]^2+x[j]+1+rnorm(1)-QM$coefficients[1]-QM$coefficients[2]*x[j]-QM$coefficients[3]*x[j]^2}
mean(le^2)
mean(qe^2)
# Out:
# [1] 62.72229
# [1] 1.043091
# plot without title
